# %%
#                                              Assignment 6

# %%
#1. Working with RDDs:
#   a) Write a Python program to create an RDD from a local data source.
#   b) Implement transformations and actions on the RDD to perform data processing tasks.
#   c) Analyze and manipulate data using RDD operations such as map, filter, reduce, or aggregate.



from pyspark import SparkContext

# Create a SparkContext
sc = SparkContext("local", "RDDExample")

# Create an RDD from a list of data
data = [1, 2, 3, 4, 5]
rdd = sc.parallelize(data)

# Print the RDD elements
print("RDD elements:", rdd.collect())

# Don't forget to stop the SparkContext when done
sc.stop()


from pyspark import SparkContext

# Create a SparkContext
sc = SparkContext("local", "RDDTransformations")

# Create an RDD from a list of data
data = [1, 2, 3, 4, 5]
rdd = sc.parallelize(data)

# Perform transformations and actions on the RDD
# For example, square each element and then sum the squares
squared_rdd = rdd.map(lambda x: x ** 2)
sum_of_squares = squared_rdd.reduce(lambda x, y: x + y)

print("Squared RDD elements:", squared_rdd.collect())
print("Sum of squares:", sum_of_squares)

# Don't forget to stop the SparkContext when done
sc.stop()
# Out:
#   File "C:\Users\Ravi\AppData\Local\Temp\ipykernel_9640\4157149582.py", line 7
#     pip install pyspark
#         ^
# SyntaxError: invalid syntax

# %%
#2. Spark DataFrame Operations:
#   a) Write a Python program to load a CSV file into a Spark DataFrame.
#   b)Perform common DataFrame operations such as filtering, grouping, or joining.
#   c) Apply Spark SQL queries on the DataFrame to extract insights from the data.

from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName("DataFrameExample").getOrCreate()

# Load the CSV file into a DataFrame
csv_file_path = "path/to/your/csv_file.csv"
df = spark.read.csv(csv_file_path, header=True, inferSchema=True)

# Show the DataFrame
df.show()

# Stop the SparkSession when done
spark.stop()


from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Create a SparkSession
spark = SparkSession.builder.appName("DataFrameOperations").getOrCreate()

# Load the CSV file into a DataFrame
csv_file_path = "path/to/your/csv_file.csv"
df = spark.read.csv(csv_file_path, header=True, inferSchema=True)

# Filter data based on a condition
filtered_df = df.filter(col("age") > 30)

# Group data by a column and perform aggregation
grouped_df = df.groupBy("gender").agg({"salary": "avg", "age": "max"})

# Join two DataFrames
other_df = spark.read.csv("path/to/other/csv_file.csv", header=True, inferSchema=True)
joined_df = df.join(other_df, on="common_column")

# Show the results
filtered_df.show()
grouped_df.show()
joined_df.show()

# Stop the SparkSession when done
spark.stop()


from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName("DataFrameSQL").getOrCreate()

# Load the CSV file into a DataFrame
csv_file_path = "path/to/your/csv_file.csv"
df = spark.read.csv(csv_file_path, header=True, inferSchema=True)

# Register the DataFrame as a temporary SQL table
df.createOrReplaceTempView("people")

# Use Spark SQL to query the DataFrame
result = spark.sql("SELECT * FROM people WHERE age > 30")

# Show the results
result.show()

# Stop the SparkSession when done
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9640\3880229983.py in <module>
#       4 #   c) Apply Spark SQL queries on the DataFrame to extract insights from the data.
#       5
# ----> 6 from pyspark.sql import SparkSession
#       7
#       8 # Create a SparkSession
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
#3. Spark Streaming:
#  a) Write a Python program to create a Spark Streaming application.
#   b) Configure the application to consume data from a streaming source (e.g., Kafka or a socket).
#   c) Implement streaming transformations and actions to process and analyze the incoming data stream.

from pyspark.streaming import StreamingContext
from pyspark import SparkContext

# Create a SparkContext
sc = SparkContext("local[2]", "StreamingExample")

# Create a StreamingContext with batch interval of 1 second
ssc = StreamingContext(sc, 1)

# Define the stream source, for example, a socket
socket_stream = ssc.socketTextStream("localhost", 9999)

# Implement streaming transformations and actions
# For example, split the lines and count the words in each batch
word_counts = socket_stream.flatMap(lambda line: line.split(" ")).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)

# Print the word counts in each batch
word_counts.pprint()

# Start the streaming context
ssc.start()

# Wait for the termination signal
ssc.awaitTermination()

# Don't forget to stop the SparkContext when done
sc.stop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9640\3238095405.py in <module>
#       4 #   c) Implement streaming transformations and actions to process and analyze the incoming data stream.
#       5
# ----> 6 from pyspark.streaming import StreamingContext
#       7 from pyspark import SparkContext
#       8
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
#4. Spark SQL and Data Source Integration:
#   a) Write a Python program to connect Spark with a relational database (e.g., MySQL, PostgreSQL).
#   b)Perform SQL operations on the data stored in the database using Spark SQL.
#   c) Explore the integration capabilities of Spark with other data sources, such as Hadoop Distributed File System (HDFS) or Amazon S3.

from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName("SparkSQLDB").getOrCreate()

# Configure connection properties for the database
db_properties = {
    "user": "your_username",
    "password": "your_password",
    "driver": "org.postgresql.Driver"
}

# Connect to the database and read data into a DataFrame
db_url = "jdbc:postgresql://your_host:your_port/your_database"
table_name = "your_table"
df = spark.read.jdbc(url=db_url, table=table_name, properties=db_properties)

# Show the DataFrame
df.show()

# Stop the SparkSession when done
spark.stop()


from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName("SparkSQLDB").getOrCreate()

# Configure connection properties for the database
db_properties = {
    "user": "your_username",
    "password": "your_password",
    "driver": "org.postgresql.Driver"
}

# Connect to the database and read data into a DataFrame
db_url = "jdbc:postgresql://your_host:your_port/your_database"
table_name = "your_table"
df = spark.read.jdbc(url=db_url, table=table_name, properties=db_properties)

# Register the DataFrame as a temporary SQL table
df.createOrReplaceTempView("people")

# Use Spark SQL to query the DataFrame
result = spark.sql("SELECT * FROM people WHERE age > 30")

# Show the results
result.show()

# Stop the SparkSession when done
spark.stop()


from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName("DataSourcesIntegration").getOrCreate()

# Read data from HDFS into a DataFrame
hdfs_file_path = "hdfs://your_hdfs_path/your_file.csv"
df_from_hdfs = spark.read.csv(hdfs_file_path, header=True
# Out:
#   File "C:\Users\Ravi\AppData\Local\Temp\ipykernel_9640\3679968192.py", line 67
#     df_from_hdfs = spark.read.csv(hdfs_file_path, header=True
#                                                              ^
# SyntaxError: unexpected EOF while parsing
