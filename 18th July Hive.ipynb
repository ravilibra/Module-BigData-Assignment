# %%
#                                       Assignment

# %%
#1.  Write a Python program that uses the HiveQL language to create a table named "Employees" with columns for "id," "name," and "salary."

from pyhive import hive

# Create a connection to the Hive server
conn = hive.Connection(host='localhost', port=10000, username='your_username')

# Create a cursor
cursor = conn.cursor()

# HiveQL query to create the "Employees" table
create_table_query = """
CREATE TABLE IF NOT EXISTS Employees (
    id INT,
    name STRING,
    salary FLOAT
)
"""

# Execute the query to create the table
cursor.execute(create_table_query)

# Close the connection and cursor
cursor.close()
conn.close()

# %%
#2.  Create a Python program that retrieves records from a Hive table named "Customers" where the age is greater than 30.

from pyhive import hive

# Create a connection to the Hive server
conn = hive.Connection(host='localhost', port=10000, username='your_username')

# Create a cursor
cursor = conn.cursor()

# HiveQL query to retrieve records
query = "SELECT * FROM Customers WHERE age > 30"

# Execute the query
cursor.execute(query)

# Fetch the results
results = cursor.fetchall()

# Print the results
for row in results:
    print(row)

# Close the connection and cursor
cursor.close()
conn.close()

# %%
#3.  Write a Python script that sorts records in descending order based on the "timestamp" column in a Hive table named "Logs."

from pyhive import hive

# Create a connection to the Hive server
conn = hive.Connection(host='localhost', port=10000, username='your_username')

# Create a cursor
cursor = conn.cursor()

# HiveQL query to sort records in descending order based on "timestamp" column
query = "SELECT * FROM Logs ORDER BY timestamp DESC"

# Execute the query
cursor.execute(query)

# Fetch the results
results = cursor.fetchall()

# Print the results
for row in results:
    print(row)

# Close the connection and cursor
cursor.close()
conn.close()

# %%
#4.  Write a Python program that connects to a Hive server using PyHive library and retrieves all records from a table named "Products".

from pyhive import hive

# Create a connection to the Hive server
conn = hive.Connection(host='localhost', port=10000, username='your_username')

# Create a cursor
cursor = conn.cursor()

# HiveQL query to retrieve all records from "Products" table
query = "SELECT * FROM Products"

# Execute the query
cursor.execute(query)

# Fetch the results
results = cursor.fetchall()

# Print the results
for row in results:
    print(row)

# Close the connection and cursor
cursor.close()
conn.close()

# %%
#5.  Write a Python script that calculates the average salary of employees from a Hive table named "Employees".

from pyhive import hive

# Create a connection to the Hive server
conn = hive.Connection(host='localhost', port=10000, username='your_username')

# Create a cursor
cursor = conn.cursor()

# HiveQL query to calculate the average salary
query = "SELECT AVG(salary) FROM Employees"

# Execute the query
cursor.execute(query)

# Fetch the result
result = cursor.fetchone()[0]

# Print the result
print("Average salary of employees:", result)

# Close the connection and cursor
cursor.close()
conn.close()

# %%
#6.  Implement a Python program that uses Hive partitioning to create a partitioned table named "Sales_Data" based on the "year" and "month" columns.

from pyhive import hive

# Create a connection to the Hive server
conn = hive.Connection(host='localhost', port=10000, username='your_username')

# Create a cursor
cursor = conn.cursor()

# HiveQL query to create the partitioned table
query = """
CREATE TABLE IF NOT EXISTS Sales_Data (
    -- Other columns
    ...
)
PARTITIONED BY (year INT, month INT)
"""

# Execute the query
cursor.execute(query)

# Close the connection and cursor
cursor.close()
conn.close()

# %%
#7.  Develop a Python script that adds a new column named "email" of type string to an existing Hive table named "Employees."

from pyhive import hive

# Create a connection to the Hive server
conn = hive.Connection(host='localhost', port=10000, username='your_username')

# Create a cursor
cursor = conn.cursor()

# HiveQL query to add a new column to the existing table
query = "ALTER TABLE Employees ADD COLUMN email STRING"

# Execute the query
cursor.execute(query)

# Close the connection and cursor
cursor.close()
conn.close()

# %%
#8.  Create a Python program that performs an inner join between two Hive tables, "Orders" and "Customers," based on a common column.

from pyhive import hive

# Create a connection to the Hive server
conn = hive.Connection(host='localhost', port=10000, username='your_username')

# Create a cursor
cursor = conn.cursor()

# HiveQL query to perform an inner join
query = """
SELECT Orders.*, Customers.*
FROM Orders
INNER JOIN Customers
ON Orders.customer_id = Customers.customer_id
"""

# Execute the query
cursor.execute(query)

# Fetch the results
results = cursor.fetchall()

# Print the results
for row in results:
    print(row)

# Close the connection and cursor
cursor.close()
conn.close()

# %%
#9.  Implement a Python program that uses the Hive SerDe library to process JSON data stored in a Hive table named "User_Activity_Logs."

from pyhive import hive

# Create a connection to the Hive server
conn = hive.Connection(host='localhost', port=10000, username='your_username')

# Create a cursor
cursor = conn.cursor()

# HiveQL query to retrieve JSON data using the SerDe library
query = "SELECT * FROM User_Activity_Logs"

# Execute the query
cursor.execute(query)

# Fetch the results
results = cursor.fetchall()

# Print the results
for row in results:
    print(row)

# Close the connection and cursor
cursor.close()
conn.close()
